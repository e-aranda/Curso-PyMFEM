# %% [markdown]
# !pip install jupyter_tikz
#
# %load_ext jupyter_tikz
#
# %%tikz -S conductor.png
# \begin{tikzpicture}[every node/.style={scale=1.8}]
# \draw[fill=black!10] (0,0) circle (5);
# \draw[fill=black!20] (-2,-3) rectangle node{$C_2$} (-1,3);
# \draw[fill=white] (1,-3) rectangle node{$C_1$} (2,3);
# \node at (0,4) {$C_0$};
# \end{tikzpicture}
# {\LARGE
# $\begin{array}{l}
# \partial C_1 \rightarrow 99 \\
# \partial C_2 \rightarrow 100 \\
# \partial C_0 \rightarrow 2
# \end{array}$ \quad
# $\begin{array}{l}
#  C_2 \rightarrow 1 \\
#  C_0 \rightarrow 5
# \end{array}$ }
